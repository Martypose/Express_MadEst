# %%
# binarizar imagen de escala de grises
#  hacer mascaras, normalmente parte blanca la que nos interesa

import cv2 as cv
import numpy as np

from matplotlib import pyplot as plt
import pylab # this allows you to control figure size 
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # this controls figure size in the notebook

img = cv.imread("tablas.png")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)






plt.imshow(gray, cmap='gray')

# %%
blur = cv.GaussianBlur(gray, (13, 13), 0)
edges = cv.Canny(blur, 46, 21, apertureSize=3)

plt.imshow(edges, cmap='gray')

# %%
minLineLength=100
lines = cv.HoughLinesP(edges=edges,rho=1,theta=np.pi/180, threshold=100,lines=np.array([]), minLineLength=minLineLength,maxLineGap=80)

a,b,c = lines.shape
for i in range(a):
    cv.line(gray, (lines[i][0][0], lines[i][0][1]), (lines[i][0][2], lines[i][0][3]), (0, 0, 255), 3, cv2.LINE_AA)
    cv.imwrite('houghlines5.jpg',gray)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[34], line 2
#       1 minLineLength=100
# ----> 2 lines = cv.HoughLinesP(edges=edges,rho=1,theta=np.pi/180, threshold=100,lines=np.array([]), minLineLength=minLineLength,maxLineGap=80)
#       4 a,b,c = lines.shape
#       5 for i in range(a):
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'HoughLinesP'
# > Overload resolution failed:
# >  - HoughLinesP() missing required argument 'image' (pos 1)
# >  - HoughLinesP() missing required argument 'image' (pos 1)

# %%
plt.imshow(img)
